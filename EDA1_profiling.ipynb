# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
# load data from the first 5 csv-files and concatenate

df1 = pd.read_csv('data/Kickstarter000.csv')
df2 = pd.read_csv('data/Kickstarter001.csv')
df3 = pd.read_csv('data/Kickstarter002.csv')
df4 = pd.read_csv('data/Kickstarter003.csv')
df5 = pd.read_csv('data/Kickstarter004.csv')

# concatenate

df = pd.concat([df1, df2, df3, df4, df5], axis=0, ignore_index=True)

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

# %%
profile
# Out:
# Summarize dataset:   0%|          | 0/42 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     302         try:
# --> 303             return func(*args, **kwargs)
#     304         except TypeError as ex:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/pandas/describe_counts_pandas.py in pandas_describe_counts(config, series, summary)
#      32     if hashable:
# ---> 33         value_counts_with_nan = value_counts_with_nan[value_counts_with_nan > 0]
#      34
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      64                 if isinstance(other, cls):
# ---> 65                     return NotImplemented
#      66
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas/core/arraylike.py in __gt__(self, other)
#      44         return self._cmp_method(other, operator.le)
# ---> 45
#      46     @unpack_zerodim_and_defer("__gt__")
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    4947
# -> 4948         The memory footprint of `object` values is ignored by default:
#    4949
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     249     rvalues = ensure_wrapped_if_datetimelike(right)
# --> 250
#     251     rvalues = lib.item_from_zerodim(rvalues)
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     138 def _na_arithmetic_op(left, right, op, is_cmp: bool = False):
# --> 139     """
#     140     Return the result of evaluating op on the passed in values.
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas/core/computation/expressions.py in <module>
#      18
# ---> 19 from pandas.core.computation.check import NUMEXPR_INSTALLED
#      20 from pandas.core.ops import roperator
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas/core/computation/check.py in <module>
#       2
# ----> 3 ne = import_optional_dependency("numexpr", errors="warn")
#       4 NUMEXPR_INSTALLED = ne is not None
#
# TypeError: import_optional_dependency() got an unexpected keyword argument 'errors'
#
# The above exception was the direct cause of the following exception:
#
# DispatchError                             Traceback (most recent call last)
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     302         try:
# --> 303             return func(*args, **kwargs)
#     304         except TypeError as ex:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/pandas/summary_pandas.py in pandas_describe_1d(config, series, summarizer, typeset)
#      49
# ---> 50     return summarizer.summarize(config, series, dtype=vtype)
#      51
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/summarizer.py in summarize(self, config, series, dtype)
#      36         """
# ---> 37         _, _, summary = self.handle(str(dtype), config, series, {"type": str(dtype)})
#      38         return summary
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/handler.py in handle(self, dtype, *args, **kwargs)
#      61         op = compose(funcs)
# ---> 62         return op(*args)
#      63
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/handler.py in func2(*x)
#      16         def func2(*x) -> Any:
# ---> 17             res = g(*x)
#      18             if type(res) == bool:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     304         except TypeError as ex:
# --> 305             raise DispatchError(f"Function {func.__code__}") from ex
#     306
#
# DispatchError: Function <code object pandas_describe_counts at 0x1213d4d40, file "/Users/laurenthartmann/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/pandas/describe_counts_pandas.py", line 9>
#
# The above exception was the direct cause of the following exception:
#
# DispatchError                             Traceback (most recent call last)
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     302         try:
# --> 303             return func(*args, **kwargs)
#     304         except TypeError as ex:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/pandas/summary_pandas.py in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      91         with multiprocessing.pool.ThreadPool(pool_size) as executor:
# ---> 92             for i, (column, description) in enumerate(
#      93                 executor.imap_unordered(multiprocess_1d, args)
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/multiprocessing/pool.py in next(self, timeout)
#     869             return value
# --> 870         raise value
#     871
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/pandas/summary_pandas.py in multiprocess_1d(args)
#      71         column, series = args
# ---> 72         return column, describe_1d(config, series, summarizer, typeset)
#      73
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     304         except TypeError as ex:
# --> 305             raise DispatchError(f"Function {func.__code__}") from ex
#     306
#
# DispatchError: Function <code object pandas_describe_1d at 0x12140f920, file "/Users/laurenthartmann/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/pandas/summary_pandas.py", line 18>
#
# The above exception was the direct cause of the following exception:
#
# DispatchError                             Traceback (most recent call last)
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/profile_report.py in _repr_html_(self)
#     416     def _repr_html_(self) -> None:
#     417         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418         self.to_notebook_iframe()
#     419
#     420     def __repr__(self) -> str:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/profile_report.py in to_notebook_iframe(self)
#     396         with warnings.catch_warnings():
#     397             warnings.simplefilter("ignore")
# --> 398             display(get_notebook_iframe(self.config, self))
#     399
#     400     def to_widgets(self) -> None:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe(config, profile)
#      73         output = get_notebook_iframe_src(config, profile)
#      74     elif attribute == IframeAttribute.srcdoc:
# ---> 75         output = get_notebook_iframe_srcdoc(config, profile)
#      76     else:
#      77         raise ValueError(
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe_srcdoc(config, profile)
#      27     width = config.notebook.iframe.width
#      28     height = config.notebook.iframe.height
# ---> 29     src = html.escape(profile.to_html())
#      30
#      31     iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     366
#     367         """
# --> 368         return self.html
#     369
#     370     def to_json(self) -> str:
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/profile_report.py in html(self)
#     183     def html(self) -> str:
#     184         if self._html is None:
# --> 185             self._html = self._render_html()
#     186         return self._html
#     187
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/profile_report.py in _render_html(self)
#     285         from pandas_profiling.report.presentation.flavours import HTMLReport
#     286
# --> 287         report = self.report
#     288
#     289         with tqdm(
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/profile_report.py in report(self)
#     177     def report(self) -> Root:
#     178         if self._report is None:
# --> 179             self._report = get_report_structure(self.config, self.description_set)
#     180         return self._report
#     181
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/profile_report.py in description_set(self)
#     159     def description_set(self) -> Dict[str, Any]:
#     160         if self._description_set is None:
# --> 161             self._description_set = describe_df(
#     162                 self.config,
#     163                 self.df,
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/describe.py in describe(config, df, summarizer, typeset, sample)
#      69         # Variable-specific
#      70         pbar.total += len(df.columns)
# ---> 71         series_description = get_series_descriptions(
#      72             config, df, summarizer, typeset, pbar
#      73         )
#
# ~/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     303             return func(*args, **kwargs)
#     304         except TypeError as ex:
# --> 305             raise DispatchError(f"Function {func.__code__}") from ex
#     306
#     307     def evaluate(self):
#
# DispatchError: Function <code object pandas_get_series_descriptions at 0x12140fc90, file "/Users/laurenthartmann/neuefische/kickstarter-ml/.venv/lib/python3.9/site-packages/pandas_profiling/model/pandas/summary_pandas.py", line 53>
